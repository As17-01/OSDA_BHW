# %%
import pandas as pd
import pathlib
import json
from loguru import logger

import optuna
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold

from src.dataset import DatasetLoader
from src.dataset import Dataset
from src.pipeline import Pipeline
from src.tuning import objective
from src.formal_concept import FormalConcept

import warnings

warnings.filterwarnings("ignore", message="is_categorical_dtype is deprecated")
warnings.filterwarnings("ignore", message="is_sparse is deprecated")

# %%
dataset = Dataset.water
n_trials = 20
METRIC = accuracy_score
NUM_FOLDS = 5
STATE = 101

# %%
data_loader = DatasetLoader(pathlib.Path("./datasets"))

data = data_loader.load_dataset(dataset)
data, target = data.drop(columns=["target"]), data[["target"]]

data.head(3)
# Out:
#       aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 2909       0.10    25.50     0.01    2.64    0.009        7.55      0.80
# 434        2.78    13.84     0.02    1.33    0.008        6.44      0.45
# 7626       0.07    21.37     0.09    1.55    0.040        0.00      0.04
#
#       bacteria  viruses
# 2909      0.34    0.007
# 434       0.29    0.001
# 7626      0.00    0.000

# %% [markdown]
# # 0. Fit models

# %%
model_params = {
    "FormalConcept": {},
    "CatBoost": {"silent": True},
    "XGBoost": {"enable_categorical": True},
    "KNN": {},
    "RandomForest": {},
    "LogRegression": {"max_iter": 10000},
    "DecisionTree": {},
}

for model_name, params in model_params.items():
    logger.info(f"Model {model_name}")

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(),
        study_name="Choose models",
    )
    logger.info("Start hyperparams optimization")
    study.optimize(
        lambda trial: objective(trial, data, target, model_name),
        catch=(Exception,),
        gc_after_trial=True,
        n_trials=n_trials,
    )
    params.update(study.best_params)
    
    with open(f"checkpoints/{model_name}_best_params_{dataset.name}.json", 'w') as output_file:
        params_str = json.dumps(params, indent=2)
        output_file.write(params_str)
# Out:
# 2023-11-27 20:14:58.102 | INFO     | __main__:<module>:12 - Model CatBoost
# [I 2023-11-27 20:14:58,105] A new study created in memory with name: Choose models
# 2023-11-27 20:14:58.107 | INFO     | __main__:<module>:19 - Start hyperparams optimization
# 2023-11-27 20:14:58.112 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 325, 'depth': 5, 'learning_rate': 0.010387538438774773, 'l2_leaf_reg': 0.001832145274562745, 'colsample_bylevel': 0.994637657958145, 'bootstrap_type': 'Bernoulli', 'subsample': 0.1496289195568023}
# 2023-11-27 20:14:59.012 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9130434782608695
# 2023-11-27 20:14:59.765 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9085457271364318
# 2023-11-27 20:15:00.605 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9099099099099099
# [I 2023-11-27 20:15:00,614] Trial 0 finished with value: 0.9104997051024037 and parameters: {'iterations': 325, 'depth': 5, 'learning_rate': 0.010387538438774773, 'l2_leaf_reg': 0.001832145274562745, 'colsample_bylevel': 0.994637657958145, 'bootstrap_type': 'Bernoulli', 'subsample': 0.1496289195568023}. Best is trial 0 with value: 0.9104997051024037.
# 2023-11-27 20:15:00.791 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 400, 'depth': 1, 'learning_rate': 0.0019017112914533208, 'l2_leaf_reg': 0.02646845730159263, 'colsample_bylevel': 0.9540860708175463, 'bootstrap_type': 'Bernoulli', 'subsample': 0.8356887398708035}
# 2023-11-27 20:15:01.343 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:15:01.935 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:02.612 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:02,621] Trial 1 finished with value: 0.8799969384677031 and parameters: {'iterations': 400, 'depth': 1, 'learning_rate': 0.0019017112914533208, 'l2_leaf_reg': 0.02646845730159263, 'colsample_bylevel': 0.9540860708175463, 'bootstrap_type': 'Bernoulli', 'subsample': 0.8356887398708035}. Best is trial 0 with value: 0.9104997051024037.
# 2023-11-27 20:15:02.782 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 100, 'depth': 7, 'learning_rate': 0.2383966644081033, 'l2_leaf_reg': 1.0923174332667118, 'colsample_bylevel': 0.6427609140789554, 'bootstrap_type': 'Bernoulli', 'subsample': 0.40901695548761074}
# 2023-11-27 20:15:03.128 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9145427286356822
# 2023-11-27 20:15:03.425 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9130434782608695
# 2023-11-27 20:15:03.833 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9144144144144144
# [I 2023-11-27 20:15:03,840] Trial 2 finished with value: 0.9140002071036555 and parameters: {'iterations': 100, 'depth': 7, 'learning_rate': 0.2383966644081033, 'l2_leaf_reg': 1.0923174332667118, 'colsample_bylevel': 0.6427609140789554, 'bootstrap_type': 'Bernoulli', 'subsample': 0.40901695548761074}. Best is trial 2 with value: 0.9140002071036555.
# 2023-11-27 20:15:04.000 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 450, 'depth': 3, 'learning_rate': 0.016691012775940182, 'l2_leaf_reg': 0.03101549401336838, 'colsample_bylevel': 0.9090571752180592, 'bootstrap_type': 'MVS'}
# 2023-11-27 20:15:04.750 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9160419790104948
# 2023-11-27 20:15:05.551 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9130434782608695
# 2023-11-27 20:15:06.425 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9099099099099099
# [I 2023-11-27 20:15:06,435] Trial 3 finished with value: 0.9129984557270914 and parameters: {'iterations': 450, 'depth': 3, 'learning_rate': 0.016691012775940182, 'l2_leaf_reg': 0.03101549401336838, 'colsample_bylevel': 0.9090571752180592, 'bootstrap_type': 'MVS'}. Best is trial 2 with value: 0.9140002071036555.
# 2023-11-27 20:15:06.598 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 275, 'depth': 2, 'learning_rate': 0.4124109813396531, 'l2_leaf_reg': 0.2834418024074503, 'colsample_bylevel': 0.4406266507859152, 'bootstrap_type': 'Bernoulli', 'subsample': 0.7556694652741515}
# 2023-11-27 20:15:07.073 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9055472263868066
# 2023-11-27 20:15:07.484 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9145427286356822
# 2023-11-27 20:15:07.947 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8993993993993994
# [I 2023-11-27 20:15:07,954] Trial 4 finished with value: 0.9064964514739628 and parameters: {'iterations': 275, 'depth': 2, 'learning_rate': 0.4124109813396531, 'l2_leaf_reg': 0.2834418024074503, 'colsample_bylevel': 0.4406266507859152, 'bootstrap_type': 'Bernoulli', 'subsample': 0.7556694652741515}. Best is trial 2 with value: 0.9140002071036555.
# 2023-11-27 20:15:08.124 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 150, 'depth': 9, 'learning_rate': 0.6545549988172963, 'l2_leaf_reg': 0.003050238278964805, 'colsample_bylevel': 0.14955546098387293, 'bootstrap_type': 'MVS'}
# 2023-11-27 20:15:08.480 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9070464767616192
# 2023-11-27 20:15:08.757 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8830584707646177
# 2023-11-27 20:15:09.038 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8813813813813813
# [I 2023-11-27 20:15:09,046] Trial 5 finished with value: 0.890495442969206 and parameters: {'iterations': 150, 'depth': 9, 'learning_rate': 0.6545549988172963, 'l2_leaf_reg': 0.003050238278964805, 'colsample_bylevel': 0.14955546098387293, 'bootstrap_type': 'MVS'}. Best is trial 2 with value: 0.9140002071036555.
# 2023-11-27 20:15:09.216 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 325, 'depth': 1, 'learning_rate': 0.008756617637613703, 'l2_leaf_reg': 0.0025695523757131517, 'colsample_bylevel': 0.07866727641186545, 'bootstrap_type': 'MVS'}
# 2023-11-27 20:15:09.647 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:15:10.152 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:10.558 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:10,565] Trial 6 finished with value: 0.8799969384677031 and parameters: {'iterations': 325, 'depth': 1, 'learning_rate': 0.008756617637613703, 'l2_leaf_reg': 0.0025695523757131517, 'colsample_bylevel': 0.07866727641186545, 'bootstrap_type': 'MVS'}. Best is trial 2 with value: 0.9140002071036555.
# 2023-11-27 20:15:10.734 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 175, 'depth': 5, 'learning_rate': 0.0057449900388568875, 'l2_leaf_reg': 0.02998967376833157, 'colsample_bylevel': 0.24855966148546846, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.288703995814958}
# 2023-11-27 20:15:11.047 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:15:11.285 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:11.683 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:11,691] Trial 7 finished with value: 0.8799969384677031 and parameters: {'iterations': 175, 'depth': 5, 'learning_rate': 0.0057449900388568875, 'l2_leaf_reg': 0.02998967376833157, 'colsample_bylevel': 0.24855966148546846, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.288703995814958}. Best is trial 2 with value: 0.9140002071036555.
# 2023-11-27 20:15:11.857 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 475, 'depth': 6, 'learning_rate': 0.024601894181105546, 'l2_leaf_reg': 0.10100802745356546, 'colsample_bylevel': 0.7995128906829542, 'bootstrap_type': 'MVS'}
# 2023-11-27 20:15:13.328 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9175412293853074
# 2023-11-27 20:15:14.812 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9010494752623688
# 2023-11-27 20:15:16.186 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9174174174174174
# [I 2023-11-27 20:15:16,195] Trial 8 finished with value: 0.9120027073550312 and parameters: {'iterations': 475, 'depth': 6, 'learning_rate': 0.024601894181105546, 'l2_leaf_reg': 0.10100802745356546, 'colsample_bylevel': 0.7995128906829542, 'bootstrap_type': 'MVS'}. Best is trial 2 with value: 0.9140002071036555.
# 2023-11-27 20:15:16.369 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 300, 'depth': 2, 'learning_rate': 0.10274732852614388, 'l2_leaf_reg': 0.20254190229231844, 'colsample_bylevel': 0.5760881500082833, 'bootstrap_type': 'Bernoulli', 'subsample': 0.3280640480764607}
# 2023-11-27 20:15:16.875 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9145427286356822
# 2023-11-27 20:15:17.435 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9130434782608695
# 2023-11-27 20:15:17.941 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9129129129129129
# [I 2023-11-27 20:15:17,948] Trial 9 finished with value: 0.9134997066031549 and parameters: {'iterations': 300, 'depth': 2, 'learning_rate': 0.10274732852614388, 'l2_leaf_reg': 0.20254190229231844, 'colsample_bylevel': 0.5760881500082833, 'bootstrap_type': 'Bernoulli', 'subsample': 0.3280640480764607}. Best is trial 2 with value: 0.9140002071036555.
# 2023-11-27 20:15:18.171 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 50, 'depth': 9, 'learning_rate': 0.10725396977291403, 'l2_leaf_reg': 5.659480962397577, 'colsample_bylevel': 0.6753694070268067, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.749666132686925}
# 2023-11-27 20:15:18.670 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9175412293853074
# 2023-11-27 20:15:19.165 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9130434782608695
# 2023-11-27 20:15:19.658 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.918918918918919
# [I 2023-11-27 20:15:19,665] Trial 10 finished with value: 0.916501208855032 and parameters: {'iterations': 50, 'depth': 9, 'learning_rate': 0.10725396977291403, 'l2_leaf_reg': 5.659480962397577, 'colsample_bylevel': 0.6753694070268067, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.749666132686925}. Best is trial 10 with value: 0.916501208855032.
# 2023-11-27 20:15:19.878 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 50, 'depth': 9, 'learning_rate': 0.11902226642148164, 'l2_leaf_reg': 8.314884596297095, 'colsample_bylevel': 0.6722201045074863, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.16319093130660156}
# 2023-11-27 20:15:20.376 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9175412293853074
# 2023-11-27 20:15:20.842 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9160419790104948
# 2023-11-27 20:15:21.336 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9129129129129129
# [I 2023-11-27 20:15:21,345] Trial 11 finished with value: 0.915498707102905 and parameters: {'iterations': 50, 'depth': 9, 'learning_rate': 0.11902226642148164, 'l2_leaf_reg': 8.314884596297095, 'colsample_bylevel': 0.6722201045074863, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.16319093130660156}. Best is trial 10 with value: 0.916501208855032.
# 2023-11-27 20:15:21.565 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 50, 'depth': 9, 'learning_rate': 0.07848692106453085, 'l2_leaf_reg': 15.785511998054035, 'colsample_bylevel': 0.7221317451947682, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.15397860443077094}
# 2023-11-27 20:15:22.053 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9130434782608695
# 2023-11-27 20:15:22.521 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9160419790104948
# 2023-11-27 20:15:22.970 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9219219219219219
# [I 2023-11-27 20:15:22,978] Trial 12 finished with value: 0.9170024597310955 and parameters: {'iterations': 50, 'depth': 9, 'learning_rate': 0.07848692106453085, 'l2_leaf_reg': 15.785511998054035, 'colsample_bylevel': 0.7221317451947682, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.15397860443077094}. Best is trial 12 with value: 0.9170024597310955.
# 2023-11-27 20:15:23.193 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 50, 'depth': 8, 'learning_rate': 0.08885234541338195, 'l2_leaf_reg': 19.428189064964005, 'colsample_bylevel': 0.7682265054534874, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.1479548639220342}
# 2023-11-27 20:15:23.491 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9190404797601199
# 2023-11-27 20:15:23.750 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9115442278860569
# 2023-11-27 20:15:24.056 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9129129129129129
# [I 2023-11-27 20:15:24,063] Trial 13 finished with value: 0.91449920685303 and parameters: {'iterations': 50, 'depth': 8, 'learning_rate': 0.08885234541338195, 'l2_leaf_reg': 19.428189064964005, 'colsample_bylevel': 0.7682265054534874, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.1479548639220342}. Best is trial 12 with value: 0.9170024597310955.
# 2023-11-27 20:15:24.263 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 200, 'depth': 7, 'learning_rate': 0.04875176023005956, 'l2_leaf_reg': 3.7854438427754893, 'colsample_bylevel': 0.44292882240060943, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.2661521168717034}
# 2023-11-27 20:15:24.976 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9220389805097451
# 2023-11-27 20:15:25.649 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9100449775112444
# 2023-11-27 20:15:26.338 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9159159159159159
# [I 2023-11-27 20:15:26,345] Trial 14 finished with value: 0.9159999579789685 and parameters: {'iterations': 200, 'depth': 7, 'learning_rate': 0.04875176023005956, 'l2_leaf_reg': 3.7854438427754893, 'colsample_bylevel': 0.44292882240060943, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.2661521168717034}. Best is trial 12 with value: 0.9170024597310955.
# 2023-11-27 20:15:26.543 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 125, 'depth': 9, 'learning_rate': 0.042565508036010224, 'l2_leaf_reg': 2.7014773641431677, 'colsample_bylevel': 0.7682763502412908, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.509980939552288}
# 2023-11-27 20:15:27.499 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9190404797601199
# 2023-11-27 20:15:28.470 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9175412293853074
# 2023-11-27 20:15:29.405 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9174174174174174
# [I 2023-11-27 20:15:29,413] Trial 15 finished with value: 0.9179997088542815 and parameters: {'iterations': 125, 'depth': 9, 'learning_rate': 0.042565508036010224, 'l2_leaf_reg': 2.7014773641431677, 'colsample_bylevel': 0.7682763502412908, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.509980939552288}. Best is trial 15 with value: 0.9179997088542815.
# 2023-11-27 20:15:29.633 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 225, 'depth': 7, 'learning_rate': 0.04173975246254879, 'l2_leaf_reg': 2.0160816129241708, 'colsample_bylevel': 0.8384781735391451, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.8859691421439093}
# 2023-11-27 20:15:30.414 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9205397301349325
# 2023-11-27 20:15:31.243 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9085457271364318
# 2023-11-27 20:15:32.062 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9159159159159159
# [I 2023-11-27 20:15:32,069] Trial 16 finished with value: 0.9150004577290934 and parameters: {'iterations': 225, 'depth': 7, 'learning_rate': 0.04173975246254879, 'l2_leaf_reg': 2.0160816129241708, 'colsample_bylevel': 0.8384781735391451, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.8859691421439093}. Best is trial 15 with value: 0.9179997088542815.
# 2023-11-27 20:15:32.272 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 125, 'depth': 8, 'learning_rate': 0.26683580092692716, 'l2_leaf_reg': 18.245044328542946, 'colsample_bylevel': 0.7965190174806294, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.748933439182473}
# 2023-11-27 20:15:32.747 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9190404797601199
# 2023-11-27 20:15:33.295 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9160419790104948
# 2023-11-27 20:15:33.865 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9054054054054054
# [I 2023-11-27 20:15:33,871] Trial 17 finished with value: 0.9134959547253401 and parameters: {'iterations': 125, 'depth': 8, 'learning_rate': 0.26683580092692716, 'l2_leaf_reg': 18.245044328542946, 'colsample_bylevel': 0.7965190174806294, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.748933439182473}. Best is trial 15 with value: 0.9179997088542815.
# 2023-11-27 20:15:34.085 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 100, 'depth': 4, 'learning_rate': 0.043905635808271684, 'l2_leaf_reg': 1.0528657208493595, 'colsample_bylevel': 0.5310202682242309, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.263864477141314}
# 2023-11-27 20:15:34.330 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9055472263868066
# 2023-11-27 20:15:34.525 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9115442278860569
# 2023-11-27 20:15:34.720 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9009009009009009
# [I 2023-11-27 20:15:34,726] Trial 18 finished with value: 0.9059974517245881 and parameters: {'iterations': 100, 'depth': 4, 'learning_rate': 0.043905635808271684, 'l2_leaf_reg': 1.0528657208493595, 'colsample_bylevel': 0.5310202682242309, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.263864477141314}. Best is trial 15 with value: 0.9179997088542815.
# 2023-11-27 20:15:34.938 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 225, 'depth': 8, 'learning_rate': 0.9881579278638575, 'l2_leaf_reg': 7.608807447993554, 'colsample_bylevel': 0.8613130676731704, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.335350816905568}
# 2023-11-27 20:15:35.944 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9085457271364318
# 2023-11-27 20:15:37.020 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9055472263868066
# 2023-11-27 20:15:38.112 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9069069069069069
# [I 2023-11-27 20:15:38,121] Trial 19 finished with value: 0.906999953476715 and parameters: {'iterations': 225, 'depth': 8, 'learning_rate': 0.9881579278638575, 'l2_leaf_reg': 7.608807447993554, 'colsample_bylevel': 0.8613130676731704, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.335350816905568}. Best is trial 15 with value: 0.9179997088542815.
# 2023-11-27 20:15:38.289 | INFO     | __main__:<module>:12 - Model XGBoost
# [I 2023-11-27 20:15:38,291] A new study created in memory with name: Choose models
# 2023-11-27 20:15:38.292 | INFO     | __main__:<module>:19 - Start hyperparams optimization
# 2023-11-27 20:15:38.299 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 4, 'learning_rate': 0.013413216998422952, 'n_estimators': 350, 'min_child_weight': 4, 'gamma': 0.0004794924680776244, 'subsample': 0.09245524969835867, 'colsample_bytree': 0.12441825288249787, 'reg_alpha': 0.022326570248135526, 'reg_lambda': 2.3082199142966487e-08}
# 2023-11-27 20:15:38.816 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8845577211394303
# 2023-11-27 20:15:39.032 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:39.252 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:39,259] Trial 0 finished with value: 0.8809964387175782 and parameters: {'max_depth': 4, 'learning_rate': 0.013413216998422952, 'n_estimators': 350, 'min_child_weight': 4, 'gamma': 0.0004794924680776244, 'subsample': 0.09245524969835867, 'colsample_bytree': 0.12441825288249787, 'reg_alpha': 0.022326570248135526, 'reg_lambda': 2.3082199142966487e-08}. Best is trial 0 with value: 0.8809964387175782.
# 2023-11-27 20:15:39.421 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 7, 'learning_rate': 0.02251430503883152, 'n_estimators': 75, 'min_child_weight': 9, 'gamma': 0.00039568426463813285, 'subsample': 0.036111151535081945, 'colsample_bytree': 0.01988233041902229, 'reg_alpha': 0.0011129080304708842, 'reg_lambda': 0.025165462313271707}
# 2023-11-27 20:15:39.757 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:15:39.863 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:39.966 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:39,981] Trial 1 finished with value: 0.8799969384677031 and parameters: {'max_depth': 7, 'learning_rate': 0.02251430503883152, 'n_estimators': 75, 'min_child_weight': 9, 'gamma': 0.00039568426463813285, 'subsample': 0.036111151535081945, 'colsample_bytree': 0.01988233041902229, 'reg_alpha': 0.0011129080304708842, 'reg_lambda': 0.025165462313271707}. Best is trial 0 with value: 0.8809964387175782.
# 2023-11-27 20:15:40.141 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 1, 'learning_rate': 0.8039217294154611, 'n_estimators': 125, 'min_child_weight': 9, 'gamma': 0.00016997004100632196, 'subsample': 0.3118992213024597, 'colsample_bytree': 0.04650925479232917, 'reg_alpha': 1.852798000152172e-08, 'reg_lambda': 0.049754039699008545}
# 2023-11-27 20:15:40.460 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8950524737631185
# 2023-11-27 20:15:40.585 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:40.707 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9009009009009009
# [I 2023-11-27 20:15:40,714] Trial 2 finished with value: 0.8935036986011499 and parameters: {'max_depth': 1, 'learning_rate': 0.8039217294154611, 'n_estimators': 125, 'min_child_weight': 9, 'gamma': 0.00016997004100632196, 'subsample': 0.3118992213024597, 'colsample_bytree': 0.04650925479232917, 'reg_alpha': 1.852798000152172e-08, 'reg_lambda': 0.049754039699008545}. Best is trial 2 with value: 0.8935036986011499.
# 2023-11-27 20:15:40.874 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 8, 'learning_rate': 0.20948613275848654, 'n_estimators': 50, 'min_child_weight': 8, 'gamma': 0.6206768122323206, 'subsample': 0.2927420654779806, 'colsample_bytree': 0.12349729325084342, 'reg_alpha': 8.993090051580299e-07, 'reg_lambda': 5.276511987088418e-05}
# 2023-11-27 20:15:41.194 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8995502248875562
# 2023-11-27 20:15:41.304 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9010494752623688
# 2023-11-27 20:15:41.414 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8828828828828829
# [I 2023-11-27 20:15:41,422] Trial 3 finished with value: 0.8944941943442692 and parameters: {'max_depth': 8, 'learning_rate': 0.20948613275848654, 'n_estimators': 50, 'min_child_weight': 8, 'gamma': 0.6206768122323206, 'subsample': 0.2927420654779806, 'colsample_bytree': 0.12349729325084342, 'reg_alpha': 8.993090051580299e-07, 'reg_lambda': 5.276511987088418e-05}. Best is trial 3 with value: 0.8944941943442692.
# 2023-11-27 20:15:41.584 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 3, 'learning_rate': 0.0720843546793268, 'n_estimators': 250, 'min_child_weight': 1, 'gamma': 5.6711983414137446e-08, 'subsample': 0.028155149326805573, 'colsample_bytree': 0.038838938175119415, 'reg_alpha': 0.3261094195288302, 'reg_lambda': 3.981348644797076e-07}
# 2023-11-27 20:15:41.959 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9100449775112444
# 2023-11-27 20:15:42.134 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.9085457271364318
# 2023-11-27 20:15:42.301 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8963963963963963
# [I 2023-11-27 20:15:42,310] Trial 4 finished with value: 0.9049957003480241 and parameters: {'max_depth': 3, 'learning_rate': 0.0720843546793268, 'n_estimators': 250, 'min_child_weight': 1, 'gamma': 5.6711983414137446e-08, 'subsample': 0.028155149326805573, 'colsample_bytree': 0.038838938175119415, 'reg_alpha': 0.3261094195288302, 'reg_lambda': 3.981348644797076e-07}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:42.471 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 8, 'learning_rate': 0.4912092407096365, 'n_estimators': 275, 'min_child_weight': 10, 'gamma': 0.0006558379878931178, 'subsample': 0.9230815508164908, 'colsample_bytree': 0.02716833659682154, 'reg_alpha': 9.43115057168645e-07, 'reg_lambda': 0.026242748139161942}
# 2023-11-27 20:15:42.907 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9070464767616192
# 2023-11-27 20:15:43.144 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.896551724137931
# 2023-11-27 20:15:43.373 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8888888888888888
# [I 2023-11-27 20:15:43,381] Trial 5 finished with value: 0.8974956965961464 and parameters: {'max_depth': 8, 'learning_rate': 0.4912092407096365, 'n_estimators': 275, 'min_child_weight': 10, 'gamma': 0.0006558379878931178, 'subsample': 0.9230815508164908, 'colsample_bytree': 0.02716833659682154, 'reg_alpha': 9.43115057168645e-07, 'reg_lambda': 0.026242748139161942}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:43.540 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 6, 'learning_rate': 0.5446592997740534, 'n_estimators': 100, 'min_child_weight': 10, 'gamma': 0.00012000104461169877, 'subsample': 0.04886881813277007, 'colsample_bytree': 0.8677423590227122, 'reg_alpha': 3.452389095451981e-05, 'reg_lambda': 0.016965519162686724}
# 2023-11-27 20:15:43.899 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:15:44.096 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:44.212 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:44,220] Trial 6 finished with value: 0.8799969384677031 and parameters: {'max_depth': 6, 'learning_rate': 0.5446592997740534, 'n_estimators': 100, 'min_child_weight': 10, 'gamma': 0.00012000104461169877, 'subsample': 0.04886881813277007, 'colsample_bytree': 0.8677423590227122, 'reg_alpha': 3.452389095451981e-05, 'reg_lambda': 0.016965519162686724}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:44.378 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 9, 'learning_rate': 0.17181243433570167, 'n_estimators': 350, 'min_child_weight': 10, 'gamma': 4.0440081317537757e-07, 'subsample': 0.04718371837907937, 'colsample_bytree': 0.08453423538579323, 'reg_alpha': 0.026371645944578546, 'reg_lambda': 2.2626294880684817e-06}
# 2023-11-27 20:15:44.775 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:15:44.950 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:45.125 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:45,134] Trial 7 finished with value: 0.8799969384677031 and parameters: {'max_depth': 9, 'learning_rate': 0.17181243433570167, 'n_estimators': 350, 'min_child_weight': 10, 'gamma': 4.0440081317537757e-07, 'subsample': 0.04718371837907937, 'colsample_bytree': 0.08453423538579323, 'reg_alpha': 0.026371645944578546, 'reg_lambda': 2.2626294880684817e-06}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:45.293 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 1, 'learning_rate': 0.8482939280555, 'n_estimators': 375, 'min_child_weight': 1, 'gamma': 0.003983801557412198, 'subsample': 0.20761459547612052, 'colsample_bytree': 0.20953605065592776, 'reg_alpha': 0.0017053915927811257, 'reg_lambda': 5.403099607592897e-06}
# 2023-11-27 20:15:45.689 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8500749625187406
# 2023-11-27 20:15:45.893 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8695652173913043
# 2023-11-27 20:15:46.257 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8573573573573574
# [I 2023-11-27 20:15:46,265] Trial 8 finished with value: 0.858999179089134 and parameters: {'max_depth': 1, 'learning_rate': 0.8482939280555, 'n_estimators': 375, 'min_child_weight': 1, 'gamma': 0.003983801557412198, 'subsample': 0.20761459547612052, 'colsample_bytree': 0.20953605065592776, 'reg_alpha': 0.0017053915927811257, 'reg_lambda': 5.403099607592897e-06}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:46.428 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 5, 'learning_rate': 0.0033482840499414767, 'n_estimators': 275, 'min_child_weight': 7, 'gamma': 0.016253973462895924, 'subsample': 0.015504128841580903, 'colsample_bytree': 0.8358919413054178, 'reg_alpha': 0.0011152080314364096, 'reg_lambda': 0.12114660620301373}
# 2023-11-27 20:15:46.925 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:15:47.498 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:47.576 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:47,580] Trial 9 finished with value: 0.8799969384677031 and parameters: {'max_depth': 5, 'learning_rate': 0.0033482840499414767, 'n_estimators': 275, 'min_child_weight': 7, 'gamma': 0.016253973462895924, 'subsample': 0.015504128841580903, 'colsample_bytree': 0.8358919413054178, 'reg_alpha': 0.0011152080314364096, 'reg_lambda': 0.12114660620301373}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:47.715 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 3, 'learning_rate': 0.0653000957258713, 'n_estimators': 200, 'min_child_weight': 1, 'gamma': 1.2849614027016002e-08, 'subsample': 0.012320280466809686, 'colsample_bytree': 0.010861369951097044, 'reg_alpha': 0.940533302003304, 'reg_lambda': 1.0890341589709357e-08}
# 2023-11-27 20:15:47.783 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8845577211394303
# 2023-11-27 20:15:47.848 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:47.915 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:47,919] Trial 10 finished with value: 0.8809964387175782 and parameters: {'max_depth': 3, 'learning_rate': 0.0653000957258713, 'n_estimators': 200, 'min_child_weight': 1, 'gamma': 1.2849614027016002e-08, 'subsample': 0.012320280466809686, 'colsample_bytree': 0.010861369951097044, 'reg_alpha': 0.940533302003304, 'reg_lambda': 1.0890341589709357e-08}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:48.054 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 3, 'learning_rate': 0.08506918254065902, 'n_estimators': 500, 'min_child_weight': 4, 'gamma': 1.74722536928592e-06, 'subsample': 0.8279526932345206, 'colsample_bytree': 0.029077050873534748, 'reg_alpha': 5.78163081015406e-06, 'reg_lambda': 0.0009993249640531826}
# 2023-11-27 20:15:48.209 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9100449775112444
# 2023-11-27 20:15:48.352 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8920539730134932
# 2023-11-27 20:15:48.492 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8903903903903904
# [I 2023-11-27 20:15:48,497] Trial 11 finished with value: 0.8974964469717093 and parameters: {'max_depth': 3, 'learning_rate': 0.08506918254065902, 'n_estimators': 500, 'min_child_weight': 4, 'gamma': 1.74722536928592e-06, 'subsample': 0.8279526932345206, 'colsample_bytree': 0.029077050873534748, 'reg_alpha': 5.78163081015406e-06, 'reg_lambda': 0.0009993249640531826}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:48.632 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 3, 'learning_rate': 0.06164853757248364, 'n_estimators': 500, 'min_child_weight': 4, 'gamma': 2.659172381090933e-06, 'subsample': 0.9161178435930326, 'colsample_bytree': 0.04002901172803568, 'reg_alpha': 0.8219517885701381, 'reg_lambda': 0.00013337181975516384}
# 2023-11-27 20:15:48.788 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9115442278860569
# 2023-11-27 20:15:48.934 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8875562218890555
# 2023-11-27 20:15:49.077 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8948948948948949
# [I 2023-11-27 20:15:49,080] Trial 12 finished with value: 0.8979984482233356 and parameters: {'max_depth': 3, 'learning_rate': 0.06164853757248364, 'n_estimators': 500, 'min_child_weight': 4, 'gamma': 2.659172381090933e-06, 'subsample': 0.9161178435930326, 'colsample_bytree': 0.04002901172803568, 'reg_alpha': 0.8219517885701381, 'reg_lambda': 0.00013337181975516384}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:49.218 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 3, 'learning_rate': 0.044965198414599845, 'n_estimators': 500, 'min_child_weight': 3, 'gamma': 3.0280682641287206e-06, 'subsample': 0.11805966837121831, 'colsample_bytree': 0.04866198718570458, 'reg_alpha': 0.9815904936324585, 'reg_lambda': 3.873118427977665e-07}
# 2023-11-27 20:15:49.384 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8995502248875562
# 2023-11-27 20:15:49.507 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.904047976011994
# 2023-11-27 20:15:49.627 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9009009009009009
# [I 2023-11-27 20:15:49,630] Trial 13 finished with value: 0.9014997006001504 and parameters: {'max_depth': 3, 'learning_rate': 0.044965198414599845, 'n_estimators': 500, 'min_child_weight': 3, 'gamma': 3.0280682641287206e-06, 'subsample': 0.11805966837121831, 'colsample_bytree': 0.04866198718570458, 'reg_alpha': 0.9815904936324585, 'reg_lambda': 3.873118427977665e-07}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:49.766 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 2, 'learning_rate': 0.013976788375874396, 'n_estimators': 425, 'min_child_weight': 2, 'gamma': 1.1524300519872825e-08, 'subsample': 0.024623485171848047, 'colsample_bytree': 0.05083160906909945, 'reg_alpha': 0.07399595960678486, 'reg_lambda': 6.365285748393272e-07}
# 2023-11-27 20:15:49.872 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:15:49.960 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:50.059 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:50,063] Trial 14 finished with value: 0.8799969384677031 and parameters: {'max_depth': 2, 'learning_rate': 0.013976788375874396, 'n_estimators': 425, 'min_child_weight': 2, 'gamma': 1.1524300519872825e-08, 'subsample': 0.024623485171848047, 'colsample_bytree': 0.05083160906909945, 'reg_alpha': 0.07399595960678486, 'reg_lambda': 6.365285748393272e-07}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:50.196 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 5, 'learning_rate': 0.0010545269809596233, 'n_estimators': 200, 'min_child_weight': 3, 'gamma': 4.946978683593581e-06, 'subsample': 0.09408437878887309, 'colsample_bytree': 0.015916283766155327, 'reg_alpha': 0.19953464420657932, 'reg_lambda': 1.3796816889639804e-07}
# 2023-11-27 20:15:50.280 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:15:50.362 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:50.442 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:50,446] Trial 15 finished with value: 0.8799969384677031 and parameters: {'max_depth': 5, 'learning_rate': 0.0010545269809596233, 'n_estimators': 200, 'min_child_weight': 3, 'gamma': 4.946978683593581e-06, 'subsample': 0.09408437878887309, 'colsample_bytree': 0.015916283766155327, 'reg_alpha': 0.19953464420657932, 'reg_lambda': 1.3796816889639804e-07}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:50.582 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 4, 'learning_rate': 0.03897968998341722, 'n_estimators': 175, 'min_child_weight': 2, 'gamma': 2.1437893703626685e-07, 'subsample': 0.010123260593828119, 'colsample_bytree': 0.07712540743235088, 'reg_alpha': 0.009959695976629868, 'reg_lambda': 1.1138516648251481e-07}
# 2023-11-27 20:15:50.643 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:15:50.706 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:50.771 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:50,775] Trial 16 finished with value: 0.8799969384677031 and parameters: {'max_depth': 4, 'learning_rate': 0.03897968998341722, 'n_estimators': 175, 'min_child_weight': 2, 'gamma': 2.1437893703626685e-07, 'subsample': 0.010123260593828119, 'colsample_bytree': 0.07712540743235088, 'reg_alpha': 0.009959695976629868, 'reg_lambda': 1.1138516648251481e-07}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:50.911 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 2, 'learning_rate': 0.15592913844114953, 'n_estimators': 425, 'min_child_weight': 6, 'gamma': 3.6160865711716716e-05, 'subsample': 0.025131606576606305, 'colsample_bytree': 0.011335239143162661, 'reg_alpha': 0.1460730741407934, 'reg_lambda': 4.179471844770726e-06}
# 2023-11-27 20:15:51.001 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:15:51.090 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:51.176 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:51,180] Trial 17 finished with value: 0.8799969384677031 and parameters: {'max_depth': 2, 'learning_rate': 0.15592913844114953, 'n_estimators': 425, 'min_child_weight': 6, 'gamma': 3.6160865711716716e-05, 'subsample': 0.025131606576606305, 'colsample_bytree': 0.011335239143162661, 'reg_alpha': 0.1460730741407934, 'reg_lambda': 4.179471844770726e-06}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:51.316 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 4, 'learning_rate': 0.029985707187856727, 'n_estimators': 250, 'min_child_weight': 5, 'gamma': 9.676127769674638e-08, 'subsample': 0.06690456046454049, 'colsample_bytree': 0.023893002753631813, 'reg_alpha': 0.5591697038021883, 'reg_lambda': 3.6025527890011687e-07}
# 2023-11-27 20:15:51.392 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:15:51.468 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:51.545 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:51,549] Trial 18 finished with value: 0.8799969384677031 and parameters: {'max_depth': 4, 'learning_rate': 0.029985707187856727, 'n_estimators': 250, 'min_child_weight': 5, 'gamma': 9.676127769674638e-08, 'subsample': 0.06690456046454049, 'colsample_bytree': 0.023893002753631813, 'reg_alpha': 0.5591697038021883, 'reg_lambda': 3.6025527890011687e-07}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:51.688 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 2, 'learning_rate': 0.012040718868704227, 'n_estimators': 425, 'min_child_weight': 2, 'gamma': 8.931664707961113e-06, 'subsample': 0.14441020909253902, 'colsample_bytree': 0.037813637638590504, 'reg_alpha': 0.009787964931284546, 'reg_lambda': 4.559411766002159e-08}
# 2023-11-27 20:15:51.812 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8905547226386806
# 2023-11-27 20:15:51.922 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8860569715142429
# 2023-11-27 20:15:52.033 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:15:52,037] Trial 19 finished with value: 0.8834951893422658 and parameters: {'max_depth': 2, 'learning_rate': 0.012040718868704227, 'n_estimators': 425, 'min_child_weight': 2, 'gamma': 8.931664707961113e-06, 'subsample': 0.14441020909253902, 'colsample_bytree': 0.037813637638590504, 'reg_alpha': 0.009787964931284546, 'reg_lambda': 4.559411766002159e-08}. Best is trial 4 with value: 0.9049957003480241.
# 2023-11-27 20:15:52.154 | INFO     | __main__:<module>:12 - Model KNN
# [I 2023-11-27 20:15:52,154] A new study created in memory with name: Choose models
# 2023-11-27 20:15:52.155 | INFO     | __main__:<module>:19 - Start hyperparams optimization
# 2023-11-27 20:15:52.156 | INFO     | src.tuning.objective:objective:21 - Selected config: {'n_neighbors': 12, 'algorithm': 'ball_tree'}
# 2023-11-27 20:15:52.211 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8935532233883059
# 2023-11-27 20:15:52.254 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8935532233883059
# 2023-11-27 20:15:52.296 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8963963963963963
# [I 2023-11-27 20:15:52,300] Trial 0 finished with value: 0.8945009477243361 and parameters: {'n_neighbors': 12, 'algorithm': 'ball_tree'}. Best is trial 0 with value: 0.8945009477243361.
# 2023-11-27 20:15:52.414 | INFO     | src.tuning.objective:objective:21 - Selected config: {'n_neighbors': 3, 'algorithm': 'ball_tree'}
# 2023-11-27 20:15:52.454 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8920539730134932
# 2023-11-27 20:15:52.495 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:52.535 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8873873873873874
# [I 2023-11-27 20:15:52,539] Trial 1 finished with value: 0.8879996938467702 and parameters: {'n_neighbors': 3, 'algorithm': 'ball_tree'}. Best is trial 0 with value: 0.8945009477243361.
# 2023-11-27 20:15:52.650 | INFO     | src.tuning.objective:objective:21 - Selected config: {'n_neighbors': 12, 'algorithm': 'ball_tree'}
# 2023-11-27 20:15:52.692 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8935532233883059
# 2023-11-27 20:15:52.739 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8935532233883059
# 2023-11-27 20:15:52.786 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8963963963963963
# [I 2023-11-27 20:15:52,789] Trial 2 finished with value: 0.8945009477243361 and parameters: {'n_neighbors': 12, 'algorithm': 'ball_tree'}. Best is trial 0 with value: 0.8945009477243361.
# 2023-11-27 20:15:52.903 | INFO     | src.tuning.objective:objective:21 - Selected config: {'n_neighbors': 4, 'algorithm': 'brute'}
# 2023-11-27 20:15:52.956 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9010494752623688
# 2023-11-27 20:15:52.993 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:53.028 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9009009009009009
# [I 2023-11-27 20:15:53,032] Trial 3 finished with value: 0.8955026991009 and parameters: {'n_neighbors': 4, 'algorithm': 'brute'}. Best is trial 3 with value: 0.8955026991009.
# 2023-11-27 20:15:53.145 | INFO     | src.tuning.objective:objective:21 - Selected config: {'n_neighbors': 4, 'algorithm': 'ball_tree'}
# 2023-11-27 20:15:53.185 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.9010494752623688
# 2023-11-27 20:15:53.224 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:15:53.269 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.9009009009009009
# [I 2023-11-27 20:15:53,273] Trial 4 finished with value: 0.8955026991009 and parameters: {'n_neighbors': 4, 'algorithm': 'ball_tree'}. Best is trial 3 with value: 0.8955026991009.
# 2023-11-27 20:15:53.389 | INFO     | src.tuning.objective:objective:21 - Selected config: {'n_neighbors': 17, 'algorithm': 'kd_tree'}
# 2023-11-27 20:15:53.431 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8935532233883059
# 2023-11-27 20:15:53.475 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.889055472263868
# 2023-11-27 20:15:53.517 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8963963963963963
# [I 2023-11-27 20:15:53,520] Trial 5 finished with value: 0.8930016973495234 and parameters: {'n_neighbors': 17, 'algorithm': 'kd_tree'}. Best is trial 3 with value: 0.8955026991009.
# 2023-11-27 20:15:53.634 | INFO     | src.tuning.objective:objective:21 - Selected config: {'n_neighbors': 12, 'algorithm': 'auto'}
# 2023-11-27 20:15:53.681 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8935532233883059
# 2023-11-27 20:15:53.751 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8935532233883059
# 2023-11-27 20:15:53.803 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8963963963963963
# [I 2023-11-27 20:15:53,806] Trial 6 finished with value: 0.8945009477243361 and parameters: {'n_neighbors': 12, 'algorithm': 'auto'}. Best is trial 3 with value: 0.8955026991009.
# 2023-11-27 20:15:53.921 | INFO     | src.tuning.objective:objective:21 - Selected config: {'n_neighbors': 9, 'algorithm': 'auto'}
# 2023-11-27 20:15:53.965 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.896551724137931
# 2023-11-27 20:15:54.007 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8920539730134932
# 2023-11-27 20:15:54.048 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8873873873873874
# [I 2023-11-27 20:15:54,051] Trial 7 finished with value: 0.8919976948462705 and parameters: {'n_neighbors': 9, 'algorithm': 'auto'}. Best is trial 3 with value: 0.8955026991009.
# 2023-11-27 20:15:54.168 | INFO     | src.tuning.objective:objective:21 - Selected config: {'n_neighbors': 16, 'algorithm': 'auto'}
# 2023-11-27 20:15:54.211 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8920539730134932
# 2023-11-27 20:15:54.254 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8875562218890555
# 2023-11-27 20:15:54.298 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8963963963963963
# [I 2023-11-27 20:15:54,301] Trial 8 finished with value: 0.8920021970996483 and parameters: {'n_neighbors': 16, 'algorithm': 'auto'}. Best is trial 3 with value: 0.8955026991009.
# 2023-11-27 20:15:54.414 | INFO     | src.tuning.objective:objective:21 - Selected config: {'n_neighbors': 15, 'algorithm': 'kd_tree'}
# 2023-11-27 20:15:54.454 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.8920539730134932
# 2023-11-27 20:15:54.496 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8875562218890555
# 2023-11-27 20:15:54.539 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8993993993993994
# [I 2023-11-27 20:15:54,542] Trial 9 finished with value: 0.8930031981006494 and parameters: {'n_neighbors': 15, 'algorithm': 'kd_tree'}. Best is trial 3 with value: 0.8955026991009.
# 2023-11-27 20:15:54.664 | INFO     | src.tuning.objective:objective:21 - Selected config: {'n_neighbors': 2, 'algorithm': 'brute'}
# 2023-11-27 20:15:54.697 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.896551724137931
# 2023-11-27 20:15:54.734 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8830584707646177
# 2023-11-27 20:15:54.769 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8873873873873874
# ...
# 2023-11-27 20:22:58.891 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 5.017188979647022, 'ammonia': 22.350718917494675, 'arsenic': 0.6935441164729937, 'barium': 0.21756110134906495, 'cadmium': 0.024955049110821616, 'chloramine': 6.271910722826304, 'chromium': 0.04219650592104431, 'bacteria': 0.2736289034278805, 'viruses': 0.4497700727812106, 'n_concepts': 2}
# 2023-11-27 20:23:02.115 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:23:06.484 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:23:10.172 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:23:10,176] Trial 6 finished with value: 0.8799969384677031 and parameters: {'aluminium': 5.017188979647022, 'ammonia': 22.350718917494675, 'arsenic': 0.6935441164729937, 'barium': 0.21756110134906495, 'cadmium': 0.024955049110821616, 'chloramine': 6.271910722826304, 'chromium': 0.04219650592104431, 'bacteria': 0.2736289034278805, 'viruses': 0.4497700727812106, 'n_concepts': 2}. Best is trial 0 with value: 0.8799969384677031.
# 2023-11-27 20:23:10.304 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 4.536065060635071, 'ammonia': 26.525098239717703, 'arsenic': 0.6233232107072613, 'barium': 0.5408179627534977, 'cadmium': 0.09451503268626121, 'chloramine': 2.6746659714724954, 'chromium': 0.6120363052516539, 'bacteria': 0.371814814992411, 'viruses': 0.3644496102703133, 'n_concepts': 3}
# 2023-11-27 20:23:34.578 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:24:03.720 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:24:36.346 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:24:36,350] Trial 7 finished with value: 0.8799969384677031 and parameters: {'aluminium': 4.536065060635071, 'ammonia': 26.525098239717703, 'arsenic': 0.6233232107072613, 'barium': 0.5408179627534977, 'cadmium': 0.09451503268626121, 'chloramine': 2.6746659714724954, 'chromium': 0.6120363052516539, 'bacteria': 0.371814814992411, 'viruses': 0.3644496102703133, 'n_concepts': 3}. Best is trial 0 with value: 0.8799969384677031.
# 2023-11-27 20:24:36.491 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 4.916025343366116, 'ammonia': 6.340234942102793, 'arsenic': 1.0138545926381008, 'barium': 3.4755941768038343, 'cadmium': 0.03759277349519623, 'chloramine': 1.2625807251091217, 'chromium': 0.377069341048608, 'bacteria': 0.5099166432572947, 'viruses': 0.9473913110389761, 'n_concepts': 4}
# 2023-11-27 20:24:44.153 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:24:54.075 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:24:59.955 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:24:59,959] Trial 8 finished with value: 0.8799969384677031 and parameters: {'aluminium': 4.916025343366116, 'ammonia': 6.340234942102793, 'arsenic': 1.0138545926381008, 'barium': 3.4755941768038343, 'cadmium': 0.03759277349519623, 'chloramine': 1.2625807251091217, 'chromium': 0.377069341048608, 'bacteria': 0.5099166432572947, 'viruses': 0.9473913110389761, 'n_concepts': 4}. Best is trial 0 with value: 0.8799969384677031.
# 2023-11-27 20:25:00.092 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 4.446666679489728, 'ammonia': 14.187462669765628, 'arsenic': 0.040980977743907965, 'barium': 1.0390140470091394, 'cadmium': 0.1282472969859893, 'chloramine': 3.6369713657751475, 'chromium': 0.6999684960298452, 'bacteria': 0.43723248908162915, 'viruses': 0.7088381345792832, 'n_concepts': 4}
# 2023-11-27 20:25:12.540 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:25:26.652 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:25:39.677 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:25:39,680] Trial 9 finished with value: 0.8799969384677031 and parameters: {'aluminium': 4.446666679489728, 'ammonia': 14.187462669765628, 'arsenic': 0.040980977743907965, 'barium': 1.0390140470091394, 'cadmium': 0.1282472969859893, 'chloramine': 3.6369713657751475, 'chromium': 0.6999684960298452, 'bacteria': 0.43723248908162915, 'viruses': 0.7088381345792832, 'n_concepts': 4}. Best is trial 0 with value: 0.8799969384677031.
# 2023-11-27 20:25:39.838 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 0.20832166204512514, 'ammonia': 2.1136947532162313, 'arsenic': 0.31535444667683654, 'barium': 4.794942326079332, 'cadmium': 0.0017055588338696637, 'chloramine': 8.627916980711559, 'chromium': 0.8618800486271905, 'bacteria': 0.04248902922530795, 'viruses': 0.7143302551955805, 'n_concepts': 9}
# 2023-11-27 20:25:44.692 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:25:49.152 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:25:53.652 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:25:53,656] Trial 10 finished with value: 0.8799969384677031 and parameters: {'aluminium': 0.20832166204512514, 'ammonia': 2.1136947532162313, 'arsenic': 0.31535444667683654, 'barium': 4.794942326079332, 'cadmium': 0.0017055588338696637, 'chloramine': 8.627916980711559, 'chromium': 0.8618800486271905, 'bacteria': 0.04248902922530795, 'viruses': 0.7143302551955805, 'n_concepts': 9}. Best is trial 0 with value: 0.8799969384677031.
# 2023-11-27 20:25:53.812 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 2.5515925101230965, 'ammonia': 0.24902292798104053, 'arsenic': 0.3239316608053839, 'barium': 1.507888927082125, 'cadmium': 0.07905650330171646, 'chloramine': 5.3473770189033925, 'chromium': 0.7227620411780223, 'bacteria': 0.17649512091856706, 'viruses': 0.2332299190379821, 'n_concepts': 7}
# 2023-11-27 20:26:07.144 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:26:15.161 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:26:23.559 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:26:23,563] Trial 11 finished with value: 0.8799969384677031 and parameters: {'aluminium': 2.5515925101230965, 'ammonia': 0.24902292798104053, 'arsenic': 0.3239316608053839, 'barium': 1.507888927082125, 'cadmium': 0.07905650330171646, 'chloramine': 5.3473770189033925, 'chromium': 0.7227620411780223, 'bacteria': 0.17649512091856706, 'viruses': 0.2332299190379821, 'n_concepts': 7}. Best is trial 0 with value: 0.8799969384677031.
# 2023-11-27 20:26:23.723 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 1.8190998212044132, 'ammonia': 9.483083936549683, 'arsenic': 0.7788039539984823, 'barium': 1.7408106292336263, 'cadmium': 0.01977580732781349, 'chloramine': 6.6787505678752535, 'chromium': 0.514324852873697, 'bacteria': 0.021000858200605266, 'viruses': 0.26685350394531354, 'n_concepts': 7}
# 2023-11-27 20:26:51.051 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:27:13.656 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:27:50.197 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:27:50,200] Trial 12 finished with value: 0.8799969384677031 and parameters: {'aluminium': 1.8190998212044132, 'ammonia': 9.483083936549683, 'arsenic': 0.7788039539984823, 'barium': 1.7408106292336263, 'cadmium': 0.01977580732781349, 'chloramine': 6.6787505678752535, 'chromium': 0.514324852873697, 'bacteria': 0.021000858200605266, 'viruses': 0.26685350394531354, 'n_concepts': 7}. Best is trial 0 with value: 0.8799969384677031.
# 2023-11-27 20:27:50.361 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 3.43736603163621, 'ammonia': 10.152030931858143, 'arsenic': 0.4270792449621933, 'barium': 1.5790397466727946, 'cadmium': 0.0011799015575093517, 'chloramine': 3.786675966537779, 'chromium': 0.8932841582801101, 'bacteria': 0.1914662473305916, 'viruses': 0.002879718919184815, 'n_concepts': 5}
# 2023-11-27 20:27:55.863 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:28:00.260 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:28:04.499 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:28:04,502] Trial 13 finished with value: 0.8799969384677031 and parameters: {'aluminium': 3.43736603163621, 'ammonia': 10.152030931858143, 'arsenic': 0.4270792449621933, 'barium': 1.5790397466727946, 'cadmium': 0.0011799015575093517, 'chloramine': 3.786675966537779, 'chromium': 0.8932841582801101, 'bacteria': 0.1914662473305916, 'viruses': 0.002879718919184815, 'n_concepts': 5}. Best is trial 0 with value: 0.8799969384677031.
# 2023-11-27 20:28:04.651 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 1.5803616795546058, 'ammonia': 4.187024000703776, 'arsenic': 0.789671972828157, 'barium': 1.1595244240488016, 'cadmium': 0.037244265981610195, 'chloramine': 2.475242388034144, 'chromium': 0.7455144590034292, 'bacteria': 0.3302404425899458, 'viruses': 0.59438234370131, 'n_concepts': 3}
# 2023-11-27 20:28:37.111 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:29:15.738 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:29:36.006 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:29:36,009] Trial 14 finished with value: 0.8799969384677031 and parameters: {'aluminium': 1.5803616795546058, 'ammonia': 4.187024000703776, 'arsenic': 0.789671972828157, 'barium': 1.1595244240488016, 'cadmium': 0.037244265981610195, 'chloramine': 2.475242388034144, 'chromium': 0.7455144590034292, 'bacteria': 0.3302404425899458, 'viruses': 0.59438234370131, 'n_concepts': 3}. Best is trial 0 with value: 0.8799969384677031.
# 2023-11-27 20:29:36.172 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 3.4104553572788214, 'ammonia': 12.334617763654514, 'arsenic': 0.16323926759062238, 'barium': 0.00854812809720773, 'cadmium': 0.07443719441262957, 'chloramine': 8.624161174592503, 'chromium': 0.45585256603786695, 'bacteria': 0.14768696289432698, 'viruses': 0.872883597664912, 'n_concepts': 7}
# 2023-11-27 20:29:40.824 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:29:44.903 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:29:48.528 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:29:48,532] Trial 15 finished with value: 0.8799969384677031 and parameters: {'aluminium': 3.4104553572788214, 'ammonia': 12.334617763654514, 'arsenic': 0.16323926759062238, 'barium': 0.00854812809720773, 'cadmium': 0.07443719441262957, 'chloramine': 8.624161174592503, 'chromium': 0.45585256603786695, 'bacteria': 0.14768696289432698, 'viruses': 0.872883597664912, 'n_concepts': 7}. Best is trial 0 with value: 0.8799969384677031.
# 2023-11-27 20:29:48.680 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 1.3080846494659517, 'ammonia': 6.294268817578641, 'arsenic': 0.43899500574576245, 'barium': 2.1813088791466337, 'cadmium': 0.018739736292926697, 'chloramine': 4.637603946993089, 'chromium': 0.7751689552614902, 'bacteria': 0.5259744130851182, 'viruses': 0.9965892317101648, 'n_concepts': 9}
# 2023-11-27 20:30:20.148 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:31:08.436 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:31:34.078 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:31:34,082] Trial 16 finished with value: 0.8799969384677031 and parameters: {'aluminium': 1.3080846494659517, 'ammonia': 6.294268817578641, 'arsenic': 0.43899500574576245, 'barium': 2.1813088791466337, 'cadmium': 0.018739736292926697, 'chloramine': 4.637603946993089, 'chromium': 0.7751689552614902, 'bacteria': 0.5259744130851182, 'viruses': 0.9965892317101648, 'n_concepts': 9}. Best is trial 0 with value: 0.8799969384677031.
# 2023-11-27 20:31:34.241 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 3.254179262161549, 'ammonia': 16.985911470824977, 'arsenic': 0.18506955262537395, 'barium': 1.1164719523059072, 'cadmium': 0.03894136513830147, 'chloramine': 6.482182619624206, 'chromium': 0.5919500311291066, 'bacteria': 0.19882156040751492, 'viruses': 0.8233447897178175, 'n_concepts': 4}
# 2023-11-27 20:33:12.857 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:35:30.932 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:36:37.640 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:36:37,644] Trial 17 finished with value: 0.8799969384677031 and parameters: {'aluminium': 3.254179262161549, 'ammonia': 16.985911470824977, 'arsenic': 0.18506955262537395, 'barium': 1.1164719523059072, 'cadmium': 0.03894136513830147, 'chloramine': 6.482182619624206, 'chromium': 0.5919500311291066, 'bacteria': 0.19882156040751492, 'viruses': 0.8233447897178175, 'n_concepts': 4}. Best is trial 0 with value: 0.8799969384677031.
# 2023-11-27 20:36:37.808 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 2.094729309815927, 'ammonia': 1.4368917531881369, 'arsenic': 0.5098415649864454, 'barium': 2.2231416862705062, 'cadmium': 0.09011609966850419, 'chloramine': 7.521700420517431, 'chromium': 0.7786127776205867, 'bacteria': 0.011623773035482787, 'viruses': 0.5809305412186294, 'n_concepts': 6}
# 2023-11-27 20:36:51.394 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:37:08.751 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:37:22.653 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:37:22,656] Trial 18 finished with value: 0.8799969384677031 and parameters: {'aluminium': 2.094729309815927, 'ammonia': 1.4368917531881369, 'arsenic': 0.5098415649864454, 'barium': 2.2231416862705062, 'cadmium': 0.09011609966850419, 'chloramine': 7.521700420517431, 'chromium': 0.7786127776205867, 'bacteria': 0.011623773035482787, 'viruses': 0.5809305412186294, 'n_concepts': 6}. Best is trial 0 with value: 0.8799969384677031.
# 2023-11-27 20:37:22.814 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 1.144546638349411, 'ammonia': 7.930633409941083, 'arsenic': 0.8506352741483132, 'barium': 1.8855118205908772, 'cadmium': 0.05641904676630942, 'chloramine': 4.750555082506353, 'chromium': 0.6708585146825571, 'bacteria': 0.33896118982790424, 'viruses': 0.3673783929901969, 'n_concepts': 3}
# 2023-11-27 20:38:55.604 | INFO     | src.tuning.objective:objective:35 - Fold 0: 0.881559220389805
# 2023-11-27 20:40:27.154 | INFO     | src.tuning.objective:objective:35 - Fold 1: 0.8845577211394303
# 2023-11-27 20:42:04.170 | INFO     | src.tuning.objective:objective:35 - Fold 2: 0.8738738738738738
# [I 2023-11-27 20:42:04,174] Trial 19 finished with value: 0.8799969384677031 and parameters: {'aluminium': 1.144546638349411, 'ammonia': 7.930633409941083, 'arsenic': 0.8506352741483132, 'barium': 1.8855118205908772, 'cadmium': 0.05641904676630942, 'chloramine': 4.750555082506353, 'chromium': 0.6708585146825571, 'bacteria': 0.33896118982790424, 'viruses': 0.3673783929901969, 'n_concepts': 3}. Best is trial 0 with value: 0.8799969384677031.

# %%
fold_generator = KFold(n_splits=NUM_FOLDS, shuffle=True, random_state=STATE)

models_dct = {
    "CatBoost": CatBoostClassifier(**model_params["CatBoost"]),
    "XGBoost": XGBClassifier(**model_params["XGBoost"]),
    "MostFrequent": DummyClassifier(strategy="most_frequent"),
    "KNN": KNeighborsClassifier(**model_params["KNN"]),
    "NaiveBayes": GaussianNB(),
    "RandomForest": RandomForestClassifier(**model_params["RandomForest"]),
    "LogRegression": LogisticRegression(**model_params["LogRegression"]),
    "DecisionTree": DecisionTreeClassifier(**model_params["DecisionTree"]),
    "FormalConcept": FormalConcept(thr_dict=model_params["FormalConcept"], n_concepts=model_params["FormalConcept"]["n_concepts"]),
}

# %%
summary_list = []
formal_concept_pipelines = []

for model_name, model in models_dct.items():
    logger.info(f"Model: {model_name}")
    pipeline = Pipeline(base_model=model)

    folds = fold_generator.split(data, y=target)
    for i, (train_fold_idx, test_fold_idx) in enumerate(folds):
        # logger.info(f"Fold: {i + 1} / {NUM_FOLDS}")

        train_data, train_target = data.iloc[train_fold_idx], target.iloc[train_fold_idx]
        test_data, test_target = data.iloc[test_fold_idx], target.iloc[test_fold_idx]
        
        pipeline.fit(train_data, train_target)
        predictions = pipeline.predict(test_data)

        metric_value = METRIC(test_target, predictions)

        result_dict = {
            "fold": i,
            "model": model_name,
            "metric_value": metric_value
        }
        summary_list.append(result_dict)

        if model_name == "FormalConcept":
            formal_concept_pipelines.append(pipeline)

summary = pd.DataFrame.from_records(summary_list)
summary.columns = ["fold", "model", "Accuracy"]

summary = pd.pivot_table(summary, values="Accuracy", index="fold", columns="model")

summary.to_csv(f"checkpoints/{model_name}_metrics_{dataset.name}.csv")

summary
# Out:
# 2023-11-27 20:42:04.331 | INFO     | __main__:<module>:5 - Model: CatBoost
# 2023-11-27 20:42:07.220 | INFO     | __main__:<module>:5 - Model: XGBoost
# 2023-11-27 20:42:07.621 | INFO     | __main__:<module>:5 - Model: MostFrequent
# 2023-11-27 20:42:07.756 | INFO     | __main__:<module>:5 - Model: KNN
# 2023-11-27 20:42:07.907 | INFO     | __main__:<module>:5 - Model: NaiveBayes
# 2023-11-27 20:42:08.049 | INFO     | __main__:<module>:5 - Model: RandomForest
# 2023-11-27 20:42:08.608 | INFO     | __main__:<module>:5 - Model: LogRegression
# 2023-11-27 20:42:08.808 | INFO     | __main__:<module>:5 - Model: DecisionTree
# 2023-11-27 20:42:08.983 | INFO     | __main__:<module>:5 - Model: FormalConcept
#     fold          model  Accuracy
# 0      0       CatBoost    0.9100
# 1      1       CatBoost    0.9125
# 2      2       CatBoost    0.9000
# 3      3       CatBoost    0.9200
# 4      4       CatBoost    0.9200
# 5      0        XGBoost    0.8850
# 6      1        XGBoost    0.9125
# 7      2        XGBoost    0.9025
# 8      3        XGBoost    0.8900
# 9      4        XGBoost    0.9150
# 10     0   MostFrequent    0.8925
# 11     1   MostFrequent    0.8800
# 12     2   MostFrequent    0.8750
# 13     3   MostFrequent    0.8750
# 14     4   MostFrequent    0.8775
# 15     0            KNN    0.8925
# 16     1            KNN    0.8750
# 17     2            KNN    0.8800
# 18     3            KNN    0.8950
# 19     4            KNN    0.8950
# 20     0     NaiveBayes    0.8675
# 21     1     NaiveBayes    0.8775
# 22     2     NaiveBayes    0.8800
# 23     3     NaiveBayes    0.8500
# 24     4     NaiveBayes    0.8725
# 25     0   RandomForest    0.9050
# 26     1   RandomForest    0.9075
# 27     2   RandomForest    0.9225
# 28     3   RandomForest    0.9125
# 29     4   RandomForest    0.9125
# 30     0  LogRegression    0.8875
# 31     1  LogRegression    0.8825
# 32     2  LogRegression    0.8850
# 33     3  LogRegression    0.8750
# 34     4  LogRegression    0.9000
# 35     0   DecisionTree    0.9150
# 36     1   DecisionTree    0.9050
# 37     2   DecisionTree    0.9225
# 38     3   DecisionTree    0.9125
# 39     4   DecisionTree    0.9100
# 40     0  FormalConcept    0.8925
# 41     1  FormalConcept    0.8800
# 42     2  FormalConcept    0.8750
# 43     3  FormalConcept    0.8750
# 44     4  FormalConcept    0.8775

# %% [markdown]
# # 1. Visualizations

# %%
from fcapy.visualizer import LineVizNx
import matplotlib.pyplot as plt

import neural_fca_example.neural_lib as nl

# %%
cn = formal_concept_pipelines[0].base_model.cn

vis = LineVizNx(node_label_font_size=14, node_label_func=lambda el_i, P: nl.neuron_label_func(el_i, P, set(cn.attributes))+'\n\n')

vis.init_mover_per_poset(cn.poset)
mvr = vis.mover

# %%
fig, ax = plt.subplots(figsize=(40,10))

vis.draw_poset(
    cn.poset, ax=ax,
    flg_node_indices=False,
    node_label_func=lambda el_i, P: nl.neuron_label_func(el_i, P, set(cn.attributes), only_new_attrs=True)+'\n\n',
    node_color='lightgray'
)
plt.title(f'NN based on {formal_concept_pipelines[0].base_model.n_concepts} best concepts from monotone concept lattice', loc='left', x=0.05, size=24)

plt.subplots_adjust()
plt.tight_layout()
plt.show()

# %%
edge_weights = cn.edge_weights_from_network()

import networkx as nx

fig, ax = plt.subplots(figsize=(40,10))

vis.draw_poset(
    cn.poset, ax=ax,
    flg_node_indices=False,
    node_label_func=lambda el_i, P: nl.neuron_label_func(el_i, P, set(cn.attributes), only_new_attrs=True)+'\n\n',
    edge_color=[edge_weights[edge] for edge in cn.poset.to_networkx().edges],
    edge_cmap=plt.cm.RdBu,
)
nx.draw_networkx_edge_labels(cn.poset.to_networkx(), vis.mover.pos, {k: f"{v:.1f}" for k,v in edge_weights.items()}, label_pos=0.7)

plt.title('Neural network with fitted edge weights', size=24, x=0.05, loc='left')
plt.tight_layout()
plt.subplots_adjust()
plt.savefig(f'images/fitted_network_{dataset.name}.png')
plt.show()
# Out:
# /home/aseliverstov/.cache/pypoetry/virtualenvs/osda-bhw-kYdWE48u-py3.10/lib/python3.10/site-packages/sparselinear/sparselinear.py:301: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:605.)
#   weight = torch.sparse.FloatTensor(self.indices, self.weights, (self.out_features, self.in_features))
