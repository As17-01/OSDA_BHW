# %%
import pandas as pd
import pathlib
import json
from loguru import logger

import optuna
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold

from src.dataset import DatasetLoader
from src.dataset import Dataset
from src.pipeline import Pipeline
from src.tuning import objective
from src.formal_concept import FormalConcept

import warnings

warnings.filterwarnings("ignore", message="is_categorical_dtype is deprecated")
warnings.filterwarnings("ignore", message="is_sparse is deprecated")

# %%
dataset = Dataset.water
n_trials = 20
METRIC = accuracy_score
NUM_FOLDS = 5
STATE = 101

# %%
data_loader = DatasetLoader(pathlib.Path("./datasets"))

data = data_loader.load_dataset(dataset)
data, target = data.drop(columns=["target"]), data[["target"]]

data.head(3)
# Out:
#    aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65     9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32    21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01    14.02     0.04    0.58    0.008        4.24      0.53    0.02
#
#    flouride  bacteria  viruses   lead  nitrates  nitrites  mercury  \
# 0      0.05      0.20    0.000  0.054     16.08      1.13    0.007
# 1      0.90      0.65    0.650  0.100      2.01      1.93    0.003
# 2      0.99      0.05    0.003  0.078     14.16      1.11    0.006
#
#    perchlorate  radium  selenium  silver  uranium
# 0        37.75    6.78      0.08    0.34     0.02
# 1        32.26    3.21      0.08    0.27     0.05
# 2        50.28    7.07      0.07    0.44     0.01

# %% [markdown]
# # 0. Fit models

# %%
model_params = {
    "FormalConcept": {},
    "CatBoost": {"silent": True},
    "XGBoost": {"enable_categorical": True},
    "KNN": {},
    "RandomForest": {},
    "LogRegression": {"max_iter": 10000},
    "DecisionTree": {},
}

for model_name, params in model_params.items():
    logger.info(f"Model {model_name}")

    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(),
        study_name="Choose models",
    )
    logger.info("Start hyperparams optimization")
    study.optimize(
        lambda trial: objective(trial, data, target, model_name),
        catch=(Exception,),
        gc_after_trial=True,
        n_trials=n_trials,
    )
    params.update(study.best_params)
    
    with open(f"checkpoints/{model_name}_best_params_{dataset.name}.json", 'w') as output_file:
        params_str = json.dumps(params, indent=2)
        output_file.write(params_str)
# Out:
# 2023-12-11 16:53:39.667 | INFO     | __main__:<module>:12 - Model FormalConcept
# [I 2023-12-11 16:53:39,671] A new study created in memory with name: Choose models
# 2023-12-11 16:53:39.673 | INFO     | __main__:<module>:19 - Start hyperparams optimization
# 2023-12-11 16:53:39.690 | INFO     | src.tuning.choose_model:_choose_formal_concept:111 - ['nitrites', 'bacteria', 'aluminium', 'cadmium', 'flouride', 'arsenic']
# 2023-12-11 16:53:39.693 | INFO     | src.tuning.objective:objective:21 - Selected config: {'aluminium': 0.3836210499962905, 'ammonia': 1.9744511566481662, 'arsenic': 0.6657512514585138, 'barium': 0.06328720981062032, 'cadmium': 0.07036106940768139, 'chloramine': 6.4712198123553195, 'chromium': 0.6733396348666738, 'copper': 1.2259629514109947, 'flouride': 0.36709549550725723, 'bacteria': 0.7260418269209932, 'viruses': 0.2988232584366124, 'lead': 0.16614938141170627, 'nitrates': 7.056698878543787, 'nitrites': 1.241117037120339, 'mercury': 0.004107936225251919, 'perchlorate': 58.30718168253775, 'radium': 7.112408312641415, 'selenium': 0.0353122090187752, 'silver': 0.22488463005854753, 'uranium': 0.06064120327191681, 'n_concepts': 8, 'n_epochs': 1019, 'feature_0': 13, 'feature_1': 9, 'feature_2': 0, 'feature_3': 4, 'feature_4': 8, 'feature_5': 2}
# 2023-12-11 16:55:07.181 | INFO     | src.tuning.objective:objective:35 - Fold 0 ROC AUC: 0.4987047310554326
# 2023-12-11 16:56:09.281 | INFO     | src.tuning.objective:objective:35 - Fold 1 ROC AUC: 0.7819805604466333
# 2023-12-11 16:57:28.594 | INFO     | src.tuning.objective:objective:35 - Fold 2 ROC AUC: 0.5410467285467286
# [I 2023-12-11 16:57:28,604] Trial 0 finished with value: 0.6072440066829315 and parameters: {'aluminium': 0.3836210499962905, 'ammonia': 1.9744511566481662, 'arsenic': 0.6657512514585138, 'barium': 0.06328720981062032, 'cadmium': 0.07036106940768139, 'chloramine': 6.4712198123553195, 'chromium': 0.6733396348666738, 'copper': 1.2259629514109947, 'flouride': 0.36709549550725723, 'bacteria': 0.7260418269209932, 'viruses': 0.2988232584366124, 'lead': 0.16614938141170627, 'nitrates': 7.056698878543787, 'nitrites': 1.241117037120339, 'mercury': 0.004107936225251919, 'perchlorate': 58.30718168253775, 'radium': 7.112408312641415, 'selenium': 0.0353122090187752, 'silver': 0.22488463005854753, 'uranium': 0.06064120327191681, 'n_concepts': 8, 'n_epochs': 1019, 'feature_0': 13, 'feature_1': 9, 'feature_2': 0, 'feature_3': 4, 'feature_4': 8, 'feature_5': 2}. Best is trial 0 with value: 0.6072440066829315.
# 2023-12-11 16:57:28.835 | INFO     | __main__:<module>:12 - Model CatBoost
# [I 2023-12-11 16:57:28,838] A new study created in memory with name: Choose models
# 2023-12-11 16:57:28.841 | INFO     | __main__:<module>:19 - Start hyperparams optimization
# 2023-12-11 16:57:28.846 | INFO     | src.tuning.objective:objective:21 - Selected config: {'iterations': 400, 'depth': 8, 'learning_rate': 0.39243654336173994, 'l2_leaf_reg': 10.789390603476738, 'colsample_bylevel': 0.6004716423444034, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.623509165076322}
# 2023-12-11 16:57:34.114 | INFO     | src.tuning.objective:objective:35 - Fold 0 ROC AUC: 0.9667621499450065
# 2023-12-11 16:57:38.680 | INFO     | src.tuning.objective:objective:35 - Fold 1 ROC AUC: 0.9744997632434792
# 2023-12-11 16:57:43.406 | INFO     | src.tuning.objective:objective:35 - Fold 2 ROC AUC: 0.97873725998726
# [I 2023-12-11 16:57:43,417] Trial 0 finished with value: 0.9733330577252486 and parameters: {'iterations': 400, 'depth': 8, 'learning_rate': 0.39243654336173994, 'l2_leaf_reg': 10.789390603476738, 'colsample_bylevel': 0.6004716423444034, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.623509165076322}. Best is trial 0 with value: 0.9733330577252486.
# 2023-12-11 16:57:43.626 | INFO     | __main__:<module>:12 - Model XGBoost
# [I 2023-12-11 16:57:43,628] A new study created in memory with name: Choose models
# 2023-12-11 16:57:43.629 | INFO     | __main__:<module>:19 - Start hyperparams optimization
# 2023-12-11 16:57:43.633 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 1, 'learning_rate': 0.0036694425630189754, 'n_estimators': 375, 'min_child_weight': 5, 'gamma': 0.033943413319219795, 'subsample': 0.7618498007021647, 'colsample_bytree': 0.03844760375813854, 'reg_alpha': 0.5769729732769644, 'reg_lambda': 2.3575454429954367e-05}
# 2023-12-11 16:57:52.323 | INFO     | src.tuning.objective:objective:35 - Fold 0 ROC AUC: 0.8273491773799978
# 2023-12-11 16:57:59.474 | INFO     | src.tuning.objective:objective:35 - Fold 1 ROC AUC: 0.8338110994859405
# 2023-12-11 16:58:18.360 | INFO     | src.tuning.objective:objective:35 - Fold 2 ROC AUC: 0.8503539050414051
# [I 2023-12-11 16:58:18,366] Trial 0 finished with value: 0.8371713939691143 and parameters: {'max_depth': 1, 'learning_rate': 0.0036694425630189754, 'n_estimators': 375, 'min_child_weight': 5, 'gamma': 0.033943413319219795, 'subsample': 0.7618498007021647, 'colsample_bytree': 0.03844760375813854, 'reg_alpha': 0.5769729732769644, 'reg_lambda': 2.3575454429954367e-05}. Best is trial 0 with value: 0.8371713939691143.
# 2023-12-11 16:58:18.510 | INFO     | __main__:<module>:12 - Model KNN
# [I 2023-12-11 16:58:18,511] A new study created in memory with name: Choose models
# 2023-12-11 16:58:18.512 | INFO     | __main__:<module>:19 - Start hyperparams optimization
# 2023-12-11 16:58:18.515 | INFO     | src.tuning.objective:objective:21 - Selected config: {'n_neighbors': 4, 'algorithm': 'auto'}
# 2023-12-11 16:58:18.834 | INFO     | src.tuning.objective:objective:35 - Fold 0 ROC AUC: 0.8197689331523045
# 2023-12-11 16:58:18.968 | INFO     | src.tuning.objective:objective:35 - Fold 1 ROC AUC: 0.8278773005787066
# 2023-12-11 16:58:19.203 | INFO     | src.tuning.objective:objective:35 - Fold 2 ROC AUC: 0.8364898989898991
# [I 2023-12-11 16:58:19,215] Trial 0 finished with value: 0.8280453775736367 and parameters: {'n_neighbors': 4, 'algorithm': 'auto'}. Best is trial 0 with value: 0.8280453775736367.
# 2023-12-11 16:58:19.394 | INFO     | __main__:<module>:12 - Model RandomForest
# [I 2023-12-11 16:58:19,395] A new study created in memory with name: Choose models
# 2023-12-11 16:58:19.396 | INFO     | __main__:<module>:19 - Start hyperparams optimization
# 2023-12-11 16:58:19.398 | INFO     | src.tuning.objective:objective:21 - Selected config: {'n_estimators': 719, 'max_depth': 27, 'min_samples_split': 81, 'min_samples_leaf': 21}
# 2023-12-11 16:58:24.178 | INFO     | src.tuning.objective:objective:35 - Fold 0 ROC AUC: 0.9664640165020889
# 2023-12-11 16:58:28.929 | INFO     | src.tuning.objective:objective:35 - Fold 1 ROC AUC: 0.9664117635383614
# 2023-12-11 16:58:33.665 | INFO     | src.tuning.objective:objective:35 - Fold 2 ROC AUC: 0.970716455091455
# [I 2023-12-11 16:58:33,673] Trial 0 finished with value: 0.9678640783773018 and parameters: {'n_estimators': 719, 'max_depth': 27, 'min_samples_split': 81, 'min_samples_leaf': 21}. Best is trial 0 with value: 0.9678640783773018.
# 2023-12-11 16:58:33.806 | INFO     | __main__:<module>:12 - Model LogRegression
# [I 2023-12-11 16:58:33,808] A new study created in memory with name: Choose models
# 2023-12-11 16:58:33.809 | INFO     | __main__:<module>:19 - Start hyperparams optimization
# 2023-12-11 16:58:33.810 | INFO     | src.tuning.objective:objective:21 - Selected config: {'tol': 0.00046762029288719483, 'C': 0.05870784733892203}
# 2023-12-11 16:58:34.149 | INFO     | src.tuning.objective:objective:35 - Fold 0 ROC AUC: 0.8578722672779745
# 2023-12-11 16:58:34.522 | INFO     | src.tuning.objective:objective:35 - Fold 1 ROC AUC: 0.855733052060916
# 2023-12-11 16:58:34.818 | INFO     | src.tuning.objective:objective:35 - Fold 2 ROC AUC: 0.8668540699790699
# [I 2023-12-11 16:58:34,825] Trial 0 finished with value: 0.8601531297726535 and parameters: {'tol': 0.00046762029288719483, 'C': 0.05870784733892203}. Best is trial 0 with value: 0.8601531297726535.
# 2023-12-11 16:58:34.983 | INFO     | __main__:<module>:12 - Model DecisionTree
# [I 2023-12-11 16:58:34,985] A new study created in memory with name: Choose models
# 2023-12-11 16:58:34.986 | INFO     | __main__:<module>:19 - Start hyperparams optimization
# 2023-12-11 16:58:34.987 | INFO     | src.tuning.objective:objective:21 - Selected config: {'max_depth': 2}
# 2023-12-11 16:58:35.092 | INFO     | src.tuning.objective:objective:35 - Fold 0 ROC AUC: 0.8255993220821533
# 2023-12-11 16:58:35.197 | INFO     | src.tuning.objective:objective:35 - Fold 1 ROC AUC: 0.8321155258404856
# 2023-12-11 16:58:35.307 | INFO     | src.tuning.objective:objective:35 - Fold 2 ROC AUC: 0.8608466420966421
# [I 2023-12-11 16:58:35,312] Trial 0 finished with value: 0.8395204966730937 and parameters: {'max_depth': 2}. Best is trial 0 with value: 0.8395204966730937.

# %%
fold_generator = KFold(n_splits=NUM_FOLDS, shuffle=True, random_state=STATE)

feature_names = [data.columns[feature_idx] for _key, feature_idx in model_params["FormalConcept"].items() if _key.startswith("feature")]

models_dct = {
    "CatBoost": CatBoostClassifier(**model_params["CatBoost"]),
    "XGBoost": XGBClassifier(**model_params["XGBoost"]),
    "MostFrequent": DummyClassifier(strategy="most_frequent"),
    "KNN": KNeighborsClassifier(**model_params["KNN"]),
    "NaiveBayes": GaussianNB(),
    "RandomForest": RandomForestClassifier(**model_params["RandomForest"]),
    "LogRegression": LogisticRegression(**model_params["LogRegression"]),
    "DecisionTree": DecisionTreeClassifier(**model_params["DecisionTree"]),
    "FormalConcept": FormalConcept(thr_dict=model_params["FormalConcept"], n_concepts=model_params["FormalConcept"]["n_concepts"], features=feature_names),
}

# %%
summary_list = []
formal_concept_pipelines = []

for model_name, model in models_dct.items():
    logger.info(f"Model: {model_name}")
    pipeline = Pipeline(base_model=model)

    folds = fold_generator.split(data, y=target)
    for i, (train_fold_idx, test_fold_idx) in enumerate(folds):
        # logger.info(f"Fold: {i + 1} / {NUM_FOLDS}")

        train_data, train_target = data.iloc[train_fold_idx], target.iloc[train_fold_idx]
        test_data, test_target = data.iloc[test_fold_idx], target.iloc[test_fold_idx]
        
        pipeline.fit(train_data, train_target)
        predictions = pipeline.predict(test_data)

        metric_value = METRIC(test_target, predictions)

        result_dict = {
            "fold": i,
            "model": model_name,
            "metric_value": metric_value
        }
        summary_list.append(result_dict)

        if model_name == "FormalConcept":
            formal_concept_pipelines.append(pipeline)

summary = pd.DataFrame.from_records(summary_list)
summary.columns = ["fold", "model", "Accuracy"]

summary = pd.pivot_table(summary, values="Accuracy", index="fold", columns="model")

summary.to_csv(f"checkpoints/{model_name}_metrics_{dataset.name}.csv")

summary
# Out:
# 2023-12-11 16:58:35.486 | INFO     | __main__:<module>:5 - Model: CatBoost
# 2023-12-11 16:58:52.508 | INFO     | __main__:<module>:5 - Model: XGBoost
# 2023-12-11 16:58:53.247 | INFO     | __main__:<module>:5 - Model: MostFrequent
# 2023-12-11 16:58:53.553 | INFO     | __main__:<module>:5 - Model: KNN
# 2023-12-11 16:58:53.941 | INFO     | __main__:<module>:5 - Model: NaiveBayes
# 2023-12-11 16:58:54.264 | INFO     | __main__:<module>:5 - Model: RandomForest
# 2023-12-11 16:59:15.998 | INFO     | __main__:<module>:5 - Model: LogRegression
# 2023-12-11 16:59:16.514 | INFO     | __main__:<module>:5 - Model: DecisionTree
# 2023-12-11 16:59:16.978 | INFO     | __main__:<module>:5 - Model: FormalConcept
# model  CatBoost  DecisionTree  FormalConcept       KNN  LogRegression  \
# fold
# 0      0.948125      0.915000       0.881875  0.886875       0.895000
# 1      0.939962      0.911194       0.118824  0.899312       0.903064
# 2      0.963727      0.926204       0.108818  0.914947       0.915572
# 3      0.952470      0.920575       0.888055  0.904315       0.911194
# 4      0.948718      0.921826       0.112570  0.902439       0.903064
#
# model  MostFrequent  NaiveBayes  RandomForest   XGBoost
# fold
# 0          0.881875    0.833125      0.943750  0.881875
# 1          0.881176    0.860538      0.938086  0.881176
# 2          0.891182    0.834271      0.955597  0.891182
# 3          0.888055    0.864290      0.948718  0.888055
# 4          0.887430    0.838024      0.944340  0.887430

# %% [markdown]
# # 1. Visualizations

# %%
from fcapy.visualizer import LineVizNx
import matplotlib.pyplot as plt

import neural_fca_example.neural_lib as nl

# %%
cn = formal_concept_pipelines[0].base_model.cn

vis = LineVizNx(node_label_font_size=14, node_label_func=lambda el_i, P: nl.neuron_label_func(el_i, P, set(cn.attributes))+'\n\n')

vis.init_mover_per_poset(cn.poset)
mvr = vis.mover

# %%
fig, ax = plt.subplots(figsize=(40,10))

vis.draw_poset(
    cn.poset, ax=ax,
    flg_node_indices=False,
    node_label_func=lambda el_i, P: nl.neuron_label_func(el_i, P, set(cn.attributes), only_new_attrs=True)+'\n\n',
    node_color='lightgray'
)
plt.title(f'NN based on {formal_concept_pipelines[0].base_model.n_concepts} best concepts from monotone concept lattice', loc='left', x=0.05, size=24)

plt.subplots_adjust()
plt.tight_layout()
plt.show()

# %%
edge_weights = cn.edge_weights_from_network()

import networkx as nx

fig, ax = plt.subplots(figsize=(40,10))

vis.draw_poset(
    cn.poset, ax=ax,
    flg_node_indices=False,
    node_label_func=lambda el_i, P: nl.neuron_label_func(el_i, P, set(cn.attributes), only_new_attrs=True)+'\n\n',
    edge_color=[edge_weights[edge] for edge in cn.poset.to_networkx().edges],
    edge_cmap=plt.cm.RdBu,
)
nx.draw_networkx_edge_labels(cn.poset.to_networkx(), vis.mover.pos, {k: f"{v:.1f}" for k,v in edge_weights.items()}, label_pos=0.7)

plt.title('Neural network with fitted edge weights', size=24, x=0.05, loc='left')
plt.tight_layout()
plt.subplots_adjust()
plt.savefig(f'images/fitted_network_{dataset.name}.png')
plt.show()
# Out:
# /home/aseliverstov/.cache/pypoetry/virtualenvs/osda-bhw-kYdWE48u-py3.10/lib/python3.10/site-packages/sparselinear/sparselinear.py:301: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:605.)
#   weight = torch.sparse.FloatTensor(self.indices, self.weights, (self.out_features, self.in_features))
